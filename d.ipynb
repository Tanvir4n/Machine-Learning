# %%
# Import libraries
import os
import cv2
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from keras.models import Sequential, Model
from keras.layers import (Input, Conv2D, Conv2DTranspose, concatenate, BatchNormalization, Activation, MaxPooling2D, AveragePooling2D, Dropout, Dense, Flatten)
from keras.callbacks import EarlyStopping
from keras.regularizers import l2

# %%
# ImageMaskClassifier
train_image_mask = {'images': [], 'masks': []}
test_image_mask = {'images': [], 'masks': []}

train_image_class = {'images': [], 'labels': []}
test_image_class = {'images': [], 'labels': []}

# %%
def load_image_mask(train_image_mask, test_image_mask, image_path, shape=256):
    file_names = os.listdir(image_path)
    partial_names = list(set(fn.split(')')[0] for fn in file_names))
    image_names = [name + ').png' for name in partial_names]
    mask_names = [name + ')_mask.png' for name in partial_names]
    
    train_test_split_index = int(len(image_names) * 0.8)
    
    for i, (image_name, mask_name) in enumerate(zip(image_names, mask_names)):
        image = cv2.resize(plt.imread(os.path.join(image_path, image_name)), (shape, shape))
        mask = cv2.resize(plt.imread(os.path.join(image_path, mask_name)), (shape, shape))
        
        if i < train_test_split_index:
            train_image_mask['images'].append(image)
            train_image_mask['masks'].append(mask)
        else:
            test_image_mask['images'].append(image)
            test_image_mask['masks'].append(mask)
    
    return train_image_mask, test_image_mask

# %%
def load_image_class(train_image_class, test_image_class, image_path, shape=256):
    file_names = os.listdir(image_path)
    image_class = os.path.basename(image_path)
    image_names = [fn.split(')')[0] + ').png' for fn in file_names]
    
    train_test_split_index = int(len(image_names) * 0.8)
    
    for i, image_name in enumerate(image_names):
        image = cv2.resize(plt.imread(os.path.join(image_path, image_name)), (shape, shape))
        
        if i < train_test_split_index:
            train_image_class['images'].append(image)
            train_image_class['labels'].append(image_class)
        else:
            test_image_class['images'].append(image)
            test_image_class['labels'].append(image_class)
    
    return train_image_class, test_image_class

# %%
from pathlib import Path

# Use raw string or double backslashes
base_dir = Path(r"D:\Dataset_BUSI_with_GT")
# OR
# base_dir = Path("D:\\Dataset_BUSI_with_GT")

categories = ['normal', 'benign', 'malignant']

for category in categories:
    image_dir = base_dir / category / 'images'
    mask_dir = base_dir / category / 'masks'

    print(f"Category: '{category}'")
    
    # Check images directory
    if image_dir.exists() and image_dir.is_dir():
        print(f"Images directory exists: {image_dir}")
        images = list(image_dir.iterdir())
        print(f"Number of images: {len(images)}")
    else:
        print(f"Error: Images directory does not exist: {image_dir}")
        images = []

    # Check masks directory
    if mask_dir.exists() and mask_dir.is_dir():
        print(f"Masks directory exists: {mask_dir}")
        masks = list(mask_dir.iterdir())
        print(f"Number of masks: {len(masks)}")
    else:
        print(f"Error: Masks directory does not exist: {mask_dir}")
        masks = []

    print("-" * 50)
# Out:
# Category: 'normal'
# Error: Images directory does not exist: D:\Dataset_BUSI_with_GT\normal\images
# Error: Masks directory does not exist: D:\Dataset_BUSI_with_GT\normal\masks
# --------------------------------------------------
# Category: 'benign'
# Error: Images directory does not exist: D:\Dataset_BUSI_with_GT\benign\images
# Error: Masks directory does not exist: D:\Dataset_BUSI_with_GT\benign\masks
# --------------------------------------------------
# Category: 'malignant'
# Error: Images directory does not exist: D:\Dataset_BUSI_with_GT\malignant\images
# Error: Masks directory does not exist: D:\Dataset_BUSI_with_GT\malignant\masks
# --------------------------------------------------

# %%
categories = ['benign', 'malignant']

for category in categories:
    # Use a raw string or double backslashes
    category_path = fr"D:\Dataset_BUSI_with_GT\{category}"
    # OR
    # category_path = f"D:\\Dataset_BUSI_with_GT\\{category}"

    # Load images and masks for the category
    train_image_mask, test_image_mask = load_image_mask(
        train_image_mask=train_image_mask,
        test_image_mask=test_image_mask,
        image_path=category_path
    )

    # Load images and classes for the category
    train_image_class, test_image_class = load_image_class(
        train_image_class=train_image_class,
        test_image_class=test_image_class,
        image_path=category_path
    )

# %%
# ImageMaskVisualization
plt.figure(figsize=(20, 20))

for i in range(5):
    
    plt.subplot(5, 2, i * 2 + 1)
    plt.imshow(train_image_mask['images'][i])
    plt.title(f'Ultrasound Image {i+1}')
    plt.axis('off')

   
    plt.subplot(5, 2, i * 2 + 2)
    plt.imshow(train_image_mask['masks'][i], cmap='plasma')
    plt.title(f'Mask {i+1}')
    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
# Definition of one Convolution block of the U-Net architecture
def convolutionBlock(inputTensor, filterCount, kernelSize = 3):
    convolutionBlock = Conv2D(filters = filterCount, kernel_size = (kernelSize, kernelSize), kernel_initializer = 'he_normal', padding = 'same', kernel_regularizer=l2(0.01))(inputTensor)
    convolutionBlock = BatchNormalization()(convolutionBlock)
    convolutionBlock = Activation('relu')(convolutionBlock)
    
    convolutionBlock = Conv2D(filters = filterCount, kernel_size = (kernelSize, kernelSize), kernel_initializer = 'he_normal', padding = 'same', kernel_regularizer=l2(0.01))(convolutionBlock)
    convolutionBlock = BatchNormalization()(convolutionBlock)
    convolutionBlock = Activation('relu')(convolutionBlock)
    
    return convolutionBlock

# %%
# Definition of the entire U-Net architecture
def modelArchitecture(inputTensor, filterCount = 16, dropoutRate = 0.1):
    # Initialization of the encoder
    firstConvolution = convolutionBlock(inputTensor, filterCount)
    firstLayer = AveragePooling2D((2, 2))(firstConvolution)
    firstLayer = Dropout(dropoutRate)(firstLayer)
    
    secondConvolution = convolutionBlock(firstLayer, filterCount * 2)
    secondLayer = AveragePooling2D((2, 2))(secondConvolution)
    secondLayer = Dropout(dropoutRate)(secondLayer)
    
    thirdConvolution = convolutionBlock(secondLayer, filterCount * 4)
    thirdLayer = AveragePooling2D((2, 2))(thirdConvolution)
    thirdLayer = Dropout(dropoutRate)(thirdLayer)
    
    fourthConvolution = convolutionBlock(thirdLayer, filterCount * 8)
    fourthLayer = AveragePooling2D((2, 2))(fourthConvolution)
    fourthLayer = Dropout(dropoutRate)(fourthLayer)
    
    fifthConvolution = convolutionBlock(fourthLayer, filterCount * 16)
    
    # Initialization of the decoder
    firstDeconvolution = Conv2DTranspose(filterCount * 8, (3, 3), strides = (2, 2), padding = 'same')(fifthConvolution)
    sixthLayer = concatenate([firstDeconvolution, fourthConvolution])
    sixthLayer = Dropout(dropoutRate)(sixthLayer)
    sixthConvolution = convolutionBlock(sixthLayer, filterCount * 8)
    
    secondDeconvolution = Conv2DTranspose(filterCount * 4, (3, 3), strides = (2, 2), padding = 'same')(sixthConvolution)
    seventhLayer = concatenate([secondDeconvolution, thirdConvolution])
    seventhLayer = Dropout(dropoutRate)(seventhLayer)
    seventhConvolution = convolutionBlock(seventhLayer, filterCount * 4)
    
    thirdDeconvolution = Conv2DTranspose(filterCount * 2, (3, 3), strides = (2, 2), padding = 'same')(seventhConvolution)
    eighthLayer = concatenate([thirdDeconvolution, secondConvolution])
    eighthLayer = Dropout(dropoutRate)(eighthLayer)
    eighthConvolution = convolutionBlock(eighthLayer, filterCount * 2)
    
    fourthDeconvolution = Conv2DTranspose(filterCount, (3, 3), strides = (2, 2), padding = 'same')(eighthConvolution)
    ninthLayer = concatenate([fourthDeconvolution, firstConvolution])
    ninthLayer = Dropout(dropoutRate)(ninthLayer)
    ninthConvolution = convolutionBlock(ninthLayer, filterCount)
    
    outputLayer = Conv2D(1, (1, 1), activation = 'sigmoid')(ninthConvolution)
    segmentationModel = Model(inputs = [inputTensor], outputs = [outputLayer])
    
    return segmentationModel

# %%
# Initialization of the segmentation model
inputs = Input((256, 256, 3))

segmentationModel = modelArchitecture(inputs, dropoutRate = 0.1)
segmentationModel.compile(optimizer = 'Adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
segmentationModel.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │        448 │ input_layer[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 256, 256,  │         64 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 256, 256,  │      2,320 │ activation[0][0]  │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d   │ (None, 128, 128,  │          0 │ activation_1[0][… │
# │ (AveragePooling2D)  │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128, 128,  │          0 │ average_pooling2… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 128, 128,  │      4,640 │ dropout[0][0]     │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 128, 128,  │      9,248 │ activation_2[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_1 │ (None, 64, 64,    │          0 │ activation_3[0][… │
# │ (AveragePooling2D)  │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 64, 64,    │          0 │ average_pooling2… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 64, 64,    │     18,496 │ dropout_1[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 64, 64,    │     36,928 │ activation_4[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_2 │ (None, 32, 32,    │          0 │ activation_5[0][… │
# │ (AveragePooling2D)  │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 32, 32,    │          0 │ average_pooling2… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 32, 32,    │     73,856 │ dropout_2[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 32, 32,    │    147,584 │ activation_6[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_3 │ (None, 16, 16,    │          0 │ activation_7[0][… │
# │ (AveragePooling2D)  │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 16, 16,    │          0 │ average_pooling2… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 16, 16,    │    295,168 │ dropout_3[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 16, 16,    │    590,080 │ activation_8[0][… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 32, 32,    │    295,040 │ activation_9[0][… │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 32, 32,    │          0 │ concatenate[0][0] │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 32, 32,    │    295,040 │ dropout_4[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 32, 32,    │    147,584 │ activation_10[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 64, 64,    │     73,792 │ activation_11[0]… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 64, 64,    │          0 │ concatenate_1[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 64, 64,    │     73,792 │ dropout_5[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 64, 64,    │     36,928 │ activation_12[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 128, 128,  │     18,464 │ activation_13[0]… │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 64)               │            │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 128, 128,  │          0 │ concatenate_2[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 128, 128,  │     18,464 │ dropout_6[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 128, 128,  │      9,248 │ activation_14[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 256, 256,  │      4,624 │ activation_15[0]… │
# │ (Conv2DTranspose)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 256, 256,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 32)               │            │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 256, 256,  │          0 │ concatenate_3[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 256, 256,  │      4,624 │ dropout_7[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 256, 256,  │      2,320 │ activation_16[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         64 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 256, 256,  │         17 │ activation_17[0]… │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,164,593 (8.26 MB)
#  Trainable params: 2,161,649 (8.25 MB)
#  Non-trainable params: 2,944 (11.50 KB)

# %%
from sklearn.model_selection import KFold

# Prepare data for cross-validation
images = np.array(train_image_mask['images'])
masks = np.array(train_image_mask['masks'])

# Define the number of folds
k = 5
kf = KFold(n_splits=k, shuffle=True, random_state=42)

# Initialize lists to store metrics
accuracies = []
losses = []

# Perform k-fold cross-validation
for fold, (train_idx, val_idx) in enumerate(kf.split(images)):
    print(f"Training on fold {fold + 1}/{k}")
    
    # Split data into training and validation sets
    train_images, val_images = images[train_idx], images[val_idx]
    train_masks, val_masks = masks[train_idx], masks[val_idx]
    
    # Initialize the model for each fold
    model = modelArchitecture(inputs, dropoutRate=0.1)
    model.compile(optimizer='Adam', loss='binary_crossentropy', metrics=['accuracy'])
    
    # Train the model
    history = model.fit(
        train_images, 
        train_masks,
        epochs=15,
        validation_data=(val_images, val_masks),
        callbacks=[
            EarlyStopping(
                patience=15, 
                monitor='val_loss', 
                mode='min', 
                restore_best_weights=True, 
                verbose=1
            )
        ]
    )
    
    # Store metrics
    accuracies.append(history.history['val_accuracy'][-1])
    losses.append(history.history['val_loss'][-1])

# Print average metrics across folds
print(f"Average Validation Accuracy: {np.mean(accuracies):.4f} ± {np.std(accuracies):.4f}")
print(f"Average Validation Loss: {np.mean(losses):.4f} ± {np.std(losses):.4f}")
# Out:
# Training on fold 1/5
# Epoch 1/15
# c:\Users\black\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\models\functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor']
# Received: inputs=Tensor(shape=(None, 256, 256, 3))
#   warnings.warn(msg)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 134s 8s/step - accuracy: 0.4431 - loss: 26.8872 - val_accuracy: 0.8311 - val_loss: 18.3808
# Epoch 2/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 124s 10s/step - accuracy: 0.8364 - loss: 16.3683 - val_accuracy: 0.8944 - val_loss: 11.3317
# Epoch 3/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 127s 10s/step - accuracy: 0.8942 - loss: 10.1546 - val_accuracy: 0.8956 - val_loss: 7.3484
# Epoch 4/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 220s 17s/step - accuracy: 0.9055 - loss: 6.5366 - val_accuracy: 0.8956 - val_loss: 4.9823
# Epoch 5/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 203s 16s/step - accuracy: 0.9109 - loss: 4.4235 - val_accuracy: 0.8956 - val_loss: 3.5454
# Epoch 6/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 111s 9s/step - accuracy: 0.9121 - loss: 3.1289 - val_accuracy: 0.8956 - val_loss: 2.6383
# Epoch 7/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 121s 9s/step - accuracy: 0.9099 - loss: 2.3102 - val_accuracy: 0.8956 - val_loss: 2.0516
# Epoch 8/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 119s 9s/step - accuracy: 0.9067 - loss: 1.7909 - val_accuracy: 0.8956 - val_loss: 1.6734
# Epoch 9/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 111s 9s/step - accuracy: 0.9151 - loss: 1.4240 - val_accuracy: 0.8956 - val_loss: 1.3821
# Epoch 10/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 113s 9s/step - accuracy: 0.9140 - loss: 1.1666 - val_accuracy: 0.8956 - val_loss: 1.1908
# Epoch 11/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 116s 9s/step - accuracy: 0.9096 - loss: 0.9938 - val_accuracy: 0.8956 - val_loss: 1.0479
# Epoch 12/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 116s 9s/step - accuracy: 0.9117 - loss: 0.8459 - val_accuracy: 0.8956 - val_loss: 0.9271
# Epoch 13/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 111s 9s/step - accuracy: 0.9109 - loss: 0.7444 - val_accuracy: 0.8956 - val_loss: 0.8325
# Epoch 14/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 111s 9s/step - accuracy: 0.9148 - loss: 0.6929 - val_accuracy: 0.8956 - val_loss: 0.7927
# Epoch 15/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 113s 9s/step - accuracy: 0.9160 - loss: 0.6230 - val_accuracy: 0.8956 - val_loss: 0.7306
# Restoring model weights from the end of the best epoch: 15.
# Training on fold 2/5
# Epoch 1/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 146s 9s/step - accuracy: 0.5700 - loss: 27.0032 - val_accuracy: 0.8094 - val_loss: 18.5132
# Epoch 2/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 113s 9s/step - accuracy: 0.8615 - loss: 16.4398 - val_accuracy: 0.9068 - val_loss: 11.4655
# Epoch 3/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 110s 8s/step - accuracy: 0.8976 - loss: 10.1586 - val_accuracy: 0.9068 - val_loss: 7.3925
# Epoch 4/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 110s 9s/step - accuracy: 0.9078 - loss: 6.5197 - val_accuracy: 0.9068 - val_loss: 4.9776
# Epoch 5/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 100s 8s/step - accuracy: 0.9097 - loss: 4.3874 - val_accuracy: 0.9068 - val_loss: 3.5158
# Epoch 6/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 101s 8s/step - accuracy: 0.9085 - loss: 3.0970 - val_accuracy: 0.9068 - val_loss: 2.6109
# Epoch 7/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 101s 8s/step - accuracy: 0.8960 - loss: 2.3088 - val_accuracy: 0.9068 - val_loss: 2.0478
# Epoch 8/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 100s 8s/step - accuracy: 0.9126 - loss: 1.7742 - val_accuracy: 0.9068 - val_loss: 1.7296
# Epoch 9/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 102s 8s/step - accuracy: 0.9093 - loss: 1.4665 - val_accuracy: 0.9068 - val_loss: 1.4403
# Epoch 10/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 105s 8s/step - accuracy: 0.9090 - loss: 1.2008 - val_accuracy: 0.9068 - val_loss: 1.2322
# Epoch 11/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 101s 8s/step - accuracy: 0.9142 - loss: 1.0060 - val_accuracy: 0.9068 - val_loss: 1.0721
# Epoch 12/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 107s 8s/step - accuracy: 0.9184 - loss: 0.8746 - val_accuracy: 0.9068 - val_loss: 0.9587
# Epoch 13/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 110s 8s/step - accuracy: 0.9182 - loss: 0.7724 - val_accuracy: 0.9068 - val_loss: 0.8355
# Epoch 14/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 108s 8s/step - accuracy: 0.9202 - loss: 0.6749 - val_accuracy: 0.9068 - val_loss: 0.7644
# Epoch 15/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 106s 8s/step - accuracy: 0.9280 - loss: 0.6123 - val_accuracy: 0.9068 - val_loss: 0.7063
# Restoring model weights from the end of the best epoch: 15.
# Training on fold 3/5
# Epoch 1/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 119s 8s/step - accuracy: 0.2068 - loss: 27.2487 - val_accuracy: 0.4766 - val_loss: 18.9003
# Epoch 2/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 107s 8s/step - accuracy: 0.6667 - loss: 16.5868 - val_accuracy: 0.8899 - val_loss: 11.6471
# Epoch 3/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 105s 8s/step - accuracy: 0.8950 - loss: 10.4203 - val_accuracy: 0.9076 - val_loss: 7.6561
# Epoch 4/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 102s 8s/step - accuracy: 0.9002 - loss: 6.8460 - val_accuracy: 0.9081 - val_loss: 5.2685
# Epoch 5/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 102s 8s/step - accuracy: 0.9025 - loss: 4.7229 - val_accuracy: 0.9081 - val_loss: 3.7893
# Epoch 6/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 104s 8s/step - accuracy: 0.9121 - loss: 3.3855 - val_accuracy: 0.9081 - val_loss: 2.8412
# Epoch 7/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 106s 8s/step - accuracy: 0.9105 - loss: 2.5587 - val_accuracy: 0.9081 - val_loss: 2.3513
# Epoch 8/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 102s 8s/step - accuracy: 0.9068 - loss: 2.1209 - val_accuracy: 0.9081 - val_loss: 1.9809
# Epoch 9/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 103s 8s/step - accuracy: 0.9129 - loss: 1.7373 - val_accuracy: 0.9081 - val_loss: 1.6383
# Epoch 10/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 102s 8s/step - accuracy: 0.9083 - loss: 1.4097 - val_accuracy: 0.9081 - val_loss: 1.4046
# Epoch 11/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 102s 8s/step - accuracy: 0.9018 - loss: 1.1873 - val_accuracy: 0.9081 - val_loss: 1.2255
# Epoch 12/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 107s 8s/step - accuracy: 0.9115 - loss: 1.0146 - val_accuracy: 0.9081 - val_loss: 1.0492
# Epoch 13/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 103s 8s/step - accuracy: 0.8966 - loss: 0.9007 - val_accuracy: 0.9081 - val_loss: 0.9865
# Epoch 14/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 103s 8s/step - accuracy: 0.9048 - loss: 0.8527 - val_accuracy: 0.9081 - val_loss: 0.9364
# Epoch 15/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 107s 8s/step - accuracy: 0.9112 - loss: 0.7607 - val_accuracy: 0.9081 - val_loss: 0.8201
# Restoring model weights from the end of the best epoch: 15.
# Training on fold 4/5
# Epoch 1/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 126s 8s/step - accuracy: 0.2975 - loss: 27.2025 - val_accuracy: 0.3761 - val_loss: 18.6072
# Epoch 2/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 108s 8s/step - accuracy: 0.7803 - loss: 16.5149 - val_accuracy: 0.9108 - val_loss: 11.5703
# Epoch 3/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 118s 9s/step - accuracy: 0.9015 - loss: 10.2331 - val_accuracy: 0.9123 - val_loss: 7.4283
# Epoch 4/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 104s 8s/step - accuracy: 0.9002 - loss: 6.5977 - val_accuracy: 0.9131 - val_loss: 5.0158
# Epoch 5/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 104s 8s/step - accuracy: 0.9022 - loss: 4.4712 - val_accuracy: 0.9131 - val_loss: 3.5812
# Epoch 6/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 104s 8s/step - accuracy: 0.9034 - loss: 3.1913 - val_accuracy: 0.9131 - val_loss: 2.6931
# Epoch 7/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 98s 8s/step - accuracy: 0.9044 - loss: 2.3706 - val_accuracy: 0.9131 - val_loss: 2.1625
# Epoch 8/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 107s 8s/step - accuracy: 0.9059 - loss: 1.9156 - val_accuracy: 0.9131 - val_loss: 1.7837
# Epoch 9/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 104s 8s/step - accuracy: 0.9033 - loss: 1.5384 - val_accuracy: 0.9131 - val_loss: 1.4515
# Epoch 10/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 105s 8s/step - accuracy: 0.9094 - loss: 1.2508 - val_accuracy: 0.9131 - val_loss: 1.2567
# Epoch 11/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 106s 8s/step - accuracy: 0.9080 - loss: 1.0568 - val_accuracy: 0.9131 - val_loss: 1.1338
# Epoch 12/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 103s 8s/step - accuracy: 0.9111 - loss: 0.9379 - val_accuracy: 0.9131 - val_loss: 1.0573
# Epoch 13/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 103s 8s/step - accuracy: 0.9117 - loss: 0.8623 - val_accuracy: 0.9131 - val_loss: 0.9711
# Epoch 14/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 111s 9s/step - accuracy: 0.9140 - loss: 0.7909 - val_accuracy: 0.9131 - val_loss: 0.9008
# Epoch 15/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 108s 8s/step - accuracy: 0.9276 - loss: 0.6812 - val_accuracy: 0.9131 - val_loss: 0.8281
# Restoring model weights from the end of the best epoch: 15.
# Training on fold 5/5
# Epoch 1/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 125s 8s/step - accuracy: 0.4294 - loss: 27.1136 - val_accuracy: 0.9096 - val_loss: 18.5381
# Epoch 2/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 108s 8s/step - accuracy: 0.8917 - loss: 16.5104 - val_accuracy: 0.9145 - val_loss: 11.5569
# Epoch 3/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 107s 8s/step - accuracy: 0.9069 - loss: 10.3042 - val_accuracy: 0.9146 - val_loss: 7.5091
# Epoch 4/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 112s 9s/step - accuracy: 0.9067 - loss: 6.7480 - val_accuracy: 0.9146 - val_loss: 5.1636
# Epoch 5/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 113s 9s/step - accuracy: 0.9096 - loss: 4.6450 - val_accuracy: 0.9146 - val_loss: 3.7201
# Epoch 6/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 114s 9s/step - accuracy: 0.9094 - loss: 3.3369 - val_accuracy: 0.9146 - val_loss: 2.8654
# Epoch 7/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 108s 8s/step - accuracy: 0.9007 - loss: 2.6015 - val_accuracy: 0.9146 - val_loss: 2.3055
# Epoch 8/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 108s 8s/step - accuracy: 0.8988 - loss: 2.0639 - val_accuracy: 0.9146 - val_loss: 1.8890
# Epoch 9/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 115s 9s/step - accuracy: 0.9043 - loss: 1.6620 - val_accuracy: 0.9146 - val_loss: 1.5697
# Epoch 10/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 119s 9s/step - accuracy: 0.9032 - loss: 1.3573 - val_accuracy: 0.9146 - val_loss: 1.3465
# Epoch 11/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 116s 9s/step - accuracy: 0.9108 - loss: 1.1299 - val_accuracy: 0.9146 - val_loss: 1.1768
# Epoch 12/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4354s 362s/step - accuracy: 0.9160 - loss: 0.9570 - val_accuracy: 0.9146 - val_loss: 1.0688
# Epoch 13/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 103s 8s/step - accuracy: 0.9150 - loss: 0.8497 - val_accuracy: 0.9146 - val_loss: 0.9793
# Epoch 14/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 106s 8s/step - accuracy: 0.9213 - loss: 0.7567 - val_accuracy: 0.9146 - val_loss: 0.9044
# Epoch 15/15
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 104s 8s/step - accuracy: 0.9203 - loss: 0.6854 - val_accuracy: 0.9146 - val_loss: 0.8351
# Restoring model weights from the end of the best epoch: 15.
# Average Validation Accuracy: 0.9077 ± 0.0067
# Average Validation Loss: 0.7840 ± 0.0543

# %%
# Plotting of the training process
accuracy = history.history['accuracy']
loss = history.history['loss']
epochs = range(len(accuracy))

# Convert accuracy and loss to a DataFrame for easier plotting with Seaborn
history_df = pd.DataFrame({
    'Epoch': epochs,
    'Accuracy': accuracy,
    'Loss': loss
})

# Create subplots to place the plots side by side
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Plot training accuracy using Seaborn
sns.lineplot(data=history_df, x='Epoch', y='Accuracy', ax=axes[0])
axes[0].set_title('Training Accuracy')

# Plot training loss using Seaborn
sns.lineplot(data=history_df, x='Epoch', y='Loss', ax=axes[1])
axes[1].set_title('Training Loss')

# Display the plots
plt.tight_layout()
plt.show()

# %%
# SegmentationModelPrediction
testImages = test_image_mask['images']
testMasks = test_image_mask['masks']

predictions = segmentationModel.predict(np.array(testImages))
print(predictions.shape)
# Out:
# c:\Users\black\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\models\functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor']
# Received: inputs=Tensor(shape=(32, 256, 256, 3))
#   warnings.warn(msg)
# 4/5 ━━━━━━━━━━━━━━━━━━━━ 1s 2s/step
# c:\Users\black\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\models\functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor']
# Received: inputs=Tensor(shape=(None, 256, 256, 3))
#   warnings.warn(msg)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step
# (130, 256, 256, 1)

# %%
# Plotting of the predicted masks
def plot_image_mask_comparisons(test_images, predictions, test_masks, indices, figsize=(20, 40)):
    """
    Plots ultrasound images, predicted masks, and actual masks side by side for comparison.

    Parameters:
        test_images (list/ndarray): List or array of test ultrasound images.
        predictions (list/ndarray): List or array of predicted masks.
        test_masks (list/ndarray): List or array of actual masks.
        indices (list): Indices of images to plot.
        figsize (tuple): Size of the figure.
    """
    num_samples = len(indices)
    plt.figure(figsize=figsize)

    for i, idx in enumerate(indices):
        # Plot Ultrasound Image
        plt.subplot(num_samples, 3, 3 * i + 1)
        plt.imshow(test_images[idx])
        plt.title(f'Ultrasound Image {idx}')
        plt.axis('off')

        # Plot Predicted Mask
        plt.subplot(num_samples, 3, 3 * i + 2)
        plt.imshow(predictions[idx], cmap='plasma')
        plt.title(f'Predicted Mask {idx}')
        plt.axis('off')

        # Plot Actual Mask
        plt.subplot(num_samples, 3, 3 * i + 3)
        plt.imshow(test_masks[idx], cmap='plasma')
        plt.title(f'Actual Mask {idx}')
        plt.axis('off')

    plt.tight_layout()
    plt.show()

indices_to_plot = list(range(20))  
plot_image_mask_comparisons(testImages, predictions, testMasks, indices_to_plot, figsize=(20, 40))

# %%
# SegmentationModelSaving
#segmentationModel.save('Breast_Cancer_Segmentation.h5')
segmentationModel.save('Breast_Cancer_Segmentation.keras')

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, classification_report
import numpy as np

def iou_score(y_true, y_pred):
    """Calculates Intersection over Union (IoU) score."""
    intersection = np.logical_and(y_true, y_pred).sum()
    union = np.logical_or(y_true, y_pred).sum()
    return intersection / (union + 1e-10)  # Avoid division by zero

def dice_score(y_true, y_pred):
    """Calculates Dice Coefficient."""
    intersection = np.logical_and(y_true, y_pred).sum()
    return (2. * intersection) / (y_true.sum() + y_pred.sum() + 1e-10)  # Avoid division by zero

def print_evaluation_metrics(y_true, y_pred):
    """Formats and prints evaluation metrics in a structured way."""
    acc = accuracy_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred, zero_division=0)
    iou = iou_score(y_true, y_pred)
    dice = dice_score(y_true, y_pred)
    cm = confusion_matrix(y_true, y_pred)
    class_report = classification_report(y_true, y_pred, zero_division=0)

    print("=" * 50)
    print(f"Evaluation Metrics:\nAccuracy: {acc:.4f}\nF1 Score: {f1:.4f}")
    print(f"IoU Score: {iou:.4f}\nDice Score: {dice:.4f}")
    print("\nConfusion Matrix:")
    print(cm)
    print("\nClassification Report:")
    print(class_report)
    print("=" * 50)
    
    return {"accuracy": acc, "f1_score": f1, "iou": iou, "dice": dice}

# K-Fold Cross-Validation
def k_fold_evaluation(test_masks, predictions, k=5):
    """
    Perform k-fold cross-validation on segmentation results.
    Prints Accuracy, F1-score, IoU, Dice Score, Confusion Matrix, and Classification Report.

    Parameters:
        test_masks (ndarray): Ground truth segmentation masks.
        predictions (ndarray): Model-predicted segmentation outputs.
        k (int): Number of folds.

    Returns:
        None (prints evaluation metrics across folds)
    """
    kf = KFold(n_splits=k, shuffle=True, random_state=42)
    accuracies, f1_scores, iou_scores, dice_scores = [], [], [], []

    test_masks = np.array(test_masks)
    predictions = np.array(predictions)

    for fold, (train_idx, val_idx) in enumerate(kf.split(test_masks)):
        print(f"\n********** Fold {fold+1} **********")

        # Splitting data
        test_masks_fold = test_masks[val_idx]
        predictions_fold = predictions[val_idx]

        # Ensure ground truth is binary
        test_masks_binary = (test_masks_fold > 0.5).astype(np.uint8)

        # Scale predictions & binarize
        predictions_binary = (predictions_fold / 255.0).astype(np.float32)

        # Evaluate segmentation performance
        metrics = print_evaluation_metrics(test_masks_binary.flatten(), (predictions_binary.flatten() > 0.5).astype(np.uint8))

        accuracies.append(metrics["accuracy"])
        f1_scores.append(metrics["f1_score"])
        iou_scores.append(metrics["iou"])
        dice_scores.append(metrics["dice"])

    # Print overall cross-validation results
    print("\n========== Cross-Validation Summary ==========")
    print(f"Mean Accuracy: {np.mean(accuracies):.4f} ± {np.std(accuracies):.4f}")
    print(f"Mean F1 Score: {np.mean(f1_scores):.4f} ± {np.std(f1_scores):.4f}")
    print(f"Mean IoU Score: {np.mean(iou_scores):.4f} ± {np.std(iou_scores):.4f}")
    print(f"Mean Dice Score: {np.mean(dice_scores):.4f} ± {np.std(dice_scores):.4f}")
    print("=" * 50)

# Example Usage:
# Convert test masks to binary if necessary
test_masks_binary = (np.array(testMasks) > 0.5).astype(np.uint8)

# Scale predictions and convert to float
predictions_binary = (np.array(predictions) / 255.0).astype(np.float32)

# Run k-Fold cross-validation (default k=5)
k_fold_evaluation(test_masks_binary, predictions_binary, k=5)
# Out:
# ********** Fold 1 **********
# ==================================================
# Evaluation Metrics:
# Accuracy: 0.8718
# F1 Score: 0.0000
# IoU Score: 0.0000
# Dice Score: 0.0000
#
# Confusion Matrix:
# [[1485474       0]
#  [ 218462       0]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93   1485474
#            1       0.00      0.00      0.00    218462
#
#     accuracy                           0.87   1703936
#    macro avg       0.44      0.50      0.47   1703936
# weighted avg       0.76      0.87      0.81   1703936
#
# ==================================================
#
# ********** Fold 2 **********
# ==================================================
# Evaluation Metrics:
# Accuracy: 0.9095
# F1 Score: 0.0000
# IoU Score: 0.0000
# Dice Score: 0.0000
#
# Confusion Matrix:
# [[1549671       0]
#  [ 154265       0]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95   1549671
#            1       0.00      0.00      0.00    154265
#
#     accuracy                           0.91   1703936
#    macro avg       0.45      0.50      0.48   1703936
# weighted avg       0.83      0.91      0.87   1703936
#
# ==================================================
#
# ********** Fold 3 **********
# ==================================================
# Evaluation Metrics:
# Accuracy: 0.9110
# F1 Score: 0.0000
# IoU Score: 0.0000
# Dice Score: 0.0000
#
# Confusion Matrix:
# [[1552262       0]
#  [ 151674       0]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95   1552262
#            1       0.00      0.00      0.00    151674
#
#     accuracy                           0.91   1703936
#    macro avg       0.46      0.50      0.48   1703936
# weighted avg       0.83      0.91      0.87   1703936
#
# ==================================================
#
# ********** Fold 4 **********
# ==================================================
# Evaluation Metrics:
# Accuracy: 0.8936
# F1 Score: 0.0000
# IoU Score: 0.0000
# Dice Score: 0.0000
#
# Confusion Matrix:
# [[1522656       0]
#  [ 181280       0]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94   1522656
#            1       0.00      0.00      0.00    181280
#
#     accuracy                           0.89   1703936
#    macro avg       0.45      0.50      0.47   1703936
# weighted avg       0.80      0.89      0.84   1703936
#
# ==================================================
#
# ********** Fold 5 **********
# ==================================================
# Evaluation Metrics:
# Accuracy: 0.9104
# F1 Score: 0.0000
# IoU Score: 0.0000
# Dice Score: 0.0000
#
# Confusion Matrix:
# [[1551201       0]
#  [ 152735       0]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95   1551201
#            1       0.00      0.00      0.00    152735
#
#     accuracy                           0.91   1703936
#    macro avg       0.46      0.50      0.48   1703936
# weighted avg       0.83      0.91      0.87   1703936
#
# ==================================================
#
# ========== Cross-Validation Summary ==========
# Mean Accuracy: 0.8992 ± 0.0152
# Mean F1 Score: 0.0000 ± 0.0000
# Mean IoU Score: 0.0000 ± 0.0000
# Mean Dice Score: 0.0000 ± 0.0000
# ==================================================

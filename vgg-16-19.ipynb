# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
from tensorflow import keras
import cv2
from tensorflow.keras.preprocessing.image import load_img ,img_to_array
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D,AveragePooling2D,BatchNormalization
from tensorflow.keras.layers import Dense,Activation
from tensorflow.keras.layers import Flatten,Dropout,SpatialDropout2D,AveragePooling2D,GlobalAveragePooling2D
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.optimizers import Adam

# %%
path = "D:\\Dataset_BUSI_with_GT"
dir_list = [os.path.join(path,i) for i in os.listdir(path)]
size_dict = {}
for i,value in enumerate(dir_list):
    size_dict[os.listdir(path)[i]] = len(os.listdir(value))
size_dict
# Out:
# {'benign': 891, 'malignant': 421, 'normal': 266}

# %%
import re
def clean(name):
    name = re.sub('[benign ().p]','',str(name))
    return name

# %%
df = pd.DataFrame(os.listdir(dir_list[0]))
# df = df.apply(str,axis=1)
df = df[0].apply(clean)
# print(df.info())
df = df[~df.str.contains('mask',regex =False)]
df = df.apply(int)
df_list = list(df)
type(df_list)
df_list.sort()
print(len(df_list))
# Out:
# 437

# %%
img_size = 128
img_channel = 3
X_b , Xm_b , y_b = np.zeros((437,img_size,img_size,img_channel)) , np.zeros((437,img_size,img_size,img_channel)) , np.full(437,'benign') 
X_n , Xm_n , y_n = np.zeros((133,img_size,img_size,img_channel)) , np.zeros((133,img_size,img_size,img_channel)) , np.full(133,'normal') 
X_m , Xm_m , y_m = np.zeros((210,img_size,img_size,img_channel)) , np.zeros((210,img_size,img_size,img_channel)) , np.full(210,'malignant')

# %%
img1_path = os.path.join(os.path.join(path,'benign'),os.listdir(os.path.join(path,'benign'))[1])

pil_img = load_img(img1_path,color_mode = 'rgb',target_size=(img_size,img_size))
img = img_to_array(pil_img)
img_shape = img.shape
print(img_shape)

def img_num(filename):
    
    val = 0
    
    for i in range(len(filename)) :
        if filename[i] == '(' :
            while True :
                i += 1
                if filename[i] == ')' :
                    break
                val = (val*10) + int(filename[i])
            break
    
    return val

for tumor_path in dir_list :
    for image in os.listdir(tumor_path) :
        p = os.path.join(tumor_path, image)
        pil_img = load_img(p,color_mode = 'rgb',target_size=(img_size,img_size))         # read image as  grayscale ans resize it
        
        if image[-5] == ')' :                                   #if real image 
            
            if image[0] == 'b' :
                X_b[img_num(image)-1]+= img_to_array(pil_img)  # If image is real add it
            if image[0] == 'n' :                               # to X as benign , normal
                X_n[img_num(image)-1]+= img_to_array(pil_img)  # or malignant.
            if image[0] == 'm' :
                X_m[img_num(image)-1]+= img_to_array(pil_img)
        else :                                                 #else masked image
            
            if image[0] == 'b' :
                Xm_b[img_num(image)-1]+= img_to_array(pil_img)  # Similarly add the target
            if image[0] == 'n' :                               # mask to y.
                Xm_n[img_num(image)-1]+= img_to_array(pil_img)
            if image[0] == 'm' :
                Xm_m[img_num(image)-1]+= img_to_array(pil_img)
# Out:
# (128, 128, 3)

# %%
X = np.concatenate((X_b, X_n, X_m), axis = 0)
Xm = np.concatenate((Xm_b, Xm_n, Xm_m), axis = 0)
y = np.concatenate((y_b, y_n, y_m), axis = 0)

print(X.shape)
print(Xm.shape)
print(y.shape)
X /= 255.0
Xm /= 255.0

print(X.max())
print(Xm.min())
# Out:
# (780, 128, 128, 3)
# (780, 128, 128, 3)
# (780,)
# 1.0
# 0.0

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

encoder  = OneHotEncoder()
# y = y.toarray()
y=encoder.fit_transform(y.reshape(y.shape[0],1))

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.15,shuffle=True,random_state=42)
Xm_train,Xm_test,ym_train,ym_test = train_test_split(Xm,y,test_size = 0.15,shuffle=True,random_state=42,stratify=y.toarray())

class_list = encoder.categories_
print(X_train.shape,X_test.shape)
print(y_train.shape,y_test.shape)
# Out:
# (663, 128, 128, 3) (117, 128, 128, 3)
# (663, 3) (117, 3)

# %%
from sklearn.metrics import f1_score,roc_auc_score,cohen_kappa_score
def evaluation(model,X_train,y_train,X_val,y_val,X_test,y_test,history):
    train_loss , train_acc = model.evaluate(X_train,y_train.toarray())
    val_loss, val_acc = model.evaluate(X_val,y_val.toarray())
    test_loss_value , test_accuracy = model.evaluate(X_test, y_test.toarray())
    y_pred = model.predict(X_test)
    y_pred_label = np.argmax(y_pred,axis=1)
    y_true_label = np.argmax(y_test,axis=1)
    f1_measure = f1_score(y_true_label,y_pred_label,average='weighted')
    roc_score = roc_auc_score(y_test.toarray(),y_pred)
    kappa_score = cohen_kappa_score(y_true_label,y_pred_label)
    print("Train accuracy = "+str(train_acc))
    print("Validation accuracy = "+str(val_acc))
    print('Test accuracy = ' + str(test_accuracy))
    print("f1_measure = "+str(f1_measure))
    print("KAPPA = "+str(kappa_score))
    print("roc_area = "+str(roc_score))

# %%
import matplotlib.pyplot as plt
def Train_Val_Plot(acc,val_acc,loss,val_loss):
    
    fig, (ax1, ax2) = plt.subplots(1,2, figsize= (15,10))
    fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy')
    ax1.legend(['training', 'validation'])


    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Loss')
    ax2.legend(['training', 'validation'])
    plt.show()

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint


def fit_evaluate(model,X_train,y_train,X_test,y_test,bs,Epochs,patience):
    es = EarlyStopping(monitor='val_loss', mode='min', patience=patience,restore_best_weights=True, verbose=1)
    X1_train,X_val,y1_train,y_val = train_test_split(X_train,y_train,test_size=0.1,random_state=42,stratify = y_train.toarray())
    history = model.fit(X1_train,y1_train.toarray(),batch_size = bs,epochs=Epochs,validation_data = (X_val,y_val.toarray()), callbacks=[es])
    evaluation(model,X1_train,y1_train,X_val,y_val,X_test,y_test,history)
    Train_Val_Plot(history.history['acc'],history.history['val_acc'],history.history['loss'],history.history['val_loss'])

# %%
base_model = tf.keras.applications.VGG16(
    include_top=False,
    weights="imagenet",
    input_tensor=None,
    input_shape=img_shape,
    pooling=None
)

for l in base_model.layers:
    l.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 40s 1us/step

# %%
def VGG16():

    model = Sequential()
    model.add(base_model)
    
    model.add(Flatten())
    model.add(BatchNormalization())
    model.add(Dense(512,activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(256,activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(128,activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(64,activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(3,activation='softmax'))
    
    model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['acc'])
    
    return model

# %%
model = VGG16()
model.summary()
fit_evaluate(model,X_train,y_train,X_test,y_test,16,30,4)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)              │ (None, 4, 4, 512)      │    14,714,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 8192)           │        32,768 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     4,194,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 3)              │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 19,114,947 (72.92 MB)
#  Trainable params: 4,383,875 (16.72 MB)
#  Non-trainable params: 14,731,072 (56.19 MB)
# Epoch 1/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - acc: 0.4282 - loss: 1.8260 - val_acc: 0.6418 - val_loss: 0.8913
# Epoch 2/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 57s 2s/step - acc: 0.5124 - loss: 1.7309 - val_acc: 0.6269 - val_loss: 0.8946
# Epoch 3/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 63s 2s/step - acc: 0.5120 - loss: 1.4692 - val_acc: 0.6716 - val_loss: 0.9033
# Epoch 4/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 61s 2s/step - acc: 0.6278 - loss: 1.0426 - val_acc: 0.7015 - val_loss: 0.8802
# Epoch 5/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 59s 2s/step - acc: 0.5812 - loss: 1.0830 - val_acc: 0.7015 - val_loss: 0.8474
# Epoch 6/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - acc: 0.6418 - loss: 0.9451 - val_acc: 0.7015 - val_loss: 0.8234
# Epoch 7/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 54s 1s/step - acc: 0.6570 - loss: 0.8397 - val_acc: 0.6716 - val_loss: 0.7925
# Epoch 8/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - acc: 0.6609 - loss: 0.8803 - val_acc: 0.6716 - val_loss: 0.7006
# Epoch 9/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 53s 1s/step - acc: 0.6701 - loss: 0.7497 - val_acc: 0.7313 - val_loss: 0.6590
# Epoch 10/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 54s 1s/step - acc: 0.7469 - loss: 0.6912 - val_acc: 0.7612 - val_loss: 0.6936
# Epoch 11/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 57s 2s/step - acc: 0.7369 - loss: 0.6754 - val_acc: 0.7910 - val_loss: 0.6718
# Epoch 12/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - acc: 0.7509 - loss: 0.6703 - val_acc: 0.7164 - val_loss: 0.6632
# Epoch 13/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - acc: 0.8270 - loss: 0.4573 - val_acc: 0.7164 - val_loss: 0.6166
# Epoch 14/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 54s 1s/step - acc: 0.8241 - loss: 0.4737 - val_acc: 0.7164 - val_loss: 0.6428
# Epoch 15/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - acc: 0.8638 - loss: 0.4025 - val_acc: 0.7612 - val_loss: 0.6075
# Epoch 16/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 59s 2s/step - acc: 0.8192 - loss: 0.4424 - val_acc: 0.7164 - val_loss: 0.6568
# Epoch 17/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 60s 2s/step - acc: 0.8774 - loss: 0.3343 - val_acc: 0.6866 - val_loss: 0.7278
# Epoch 18/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 60s 2s/step - acc: 0.8673 - loss: 0.4605 - val_acc: 0.7164 - val_loss: 0.7947
# Epoch 19/30
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 53s 1s/step - acc: 0.9060 - loss: 0.2349 - val_acc: 0.6716 - val_loss: 0.8600
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 15.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - acc: 0.9643 - loss: 0.1931
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - acc: 0.7517 - loss: 0.5835
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - acc: 0.7778 - loss: 0.6100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 model = VGG16()
#       2 model.summary()
# ----> 3 fit_evaluate(model,X_train,y_train,X_test,y_test,16,30,4)
#
# Cell In[12], line 9, in fit_evaluate(model, X_train, y_train, X_test, y_test, bs, Epochs, patience)
#       7 X1_train,X_val,y1_train,y_val = train_test_split(X_train,y_train,test_size=0.1,random_state=42,stratify = y_train.toarray())
#       8 history = model.fit(X1_train,y1_train.toarray(),batch_size = bs,epochs=Epochs,validation_data = (X_val,y_val.toarray()), callbacks=[es])
# ----> 9 evaluation(model,X1_train,y1_train,X_val,y_val,X_test,y_test,history)
#      10 Train_Val_Plot(history.history['acc'],history.history['val_acc'],history.history['loss'],history.history['val_loss'])
#
# Cell In[10], line 9, in evaluation(model, X_train, y_train, X_val, y_val, X_test, y_test, history)
#       7 y_pred_label = np.argmax(y_pred,axis=1)
#       8 y_true_label = np.argmax(y_test,axis=1)
# ----> 9 f1_measure = f1_score(y_true_label,y_pred_label,average='weighted')
#      10 roc_score = roc_auc_score(y_test.toarray(),y_pred)
#      11 kappa_score = cohen_kappa_score(y_true_label,y_pred_label)
#
# File c:\Users\black\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py:216, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     210 try:
#     211     with config_context(
#     212         skip_parameter_validation=(
#     213             prefer_skip_nested_validation or global_skip_validation
#     214         )
#     215     ):
# --> 216         return func(*args, **kwargs)
#     217 except InvalidParameterError as e:
#     218     # When the function is just a wrapper around an estimator, we allow
#     219     # the function to delegate validation to the estimator, but we replace
#     220     # the name of the estimator by the name of the function in the error
#     221     # message to avoid confusion.
#     222     msg = re.sub(
#     223         r"parameter of \w+ must be",
#     224         f"parameter of {func.__qualname__} must be",
#     225         str(e),
#     226     )
#
# File c:\Users\black\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1324, in f1_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    1144 @validate_params(
#    1145     {
#    1146         "y_true": ["array-like", "sparse matrix"],
#    (...)
#    1171     zero_division="warn",
#    1172 ):
#    1173     """Compute the F1 score, also known as balanced F-score or F-measure.
#    1174
#    1175     The F1 score can be interpreted as a harmonic mean of the precision and
#    (...)
#    1322     array([0.66666667, 1.        , 0.66666667])
#    1323     """
# -> 1324     return fbeta_score(
#    1325         y_true,
#    1326         y_pred,
#    1327         beta=1,
#    1328         labels=labels,
#    1329         pos_label=pos_label,
#    1330         average=average,
#    1331         sample_weight=sample_weight,
#    1332         zero_division=zero_division,
#    1333     )
#
# File c:\Users\black\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py:189, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     187 global_skip_validation = get_config()["skip_parameter_validation"]
#     188 if global_skip_validation:
# --> 189     return func(*args, **kwargs)
#     191 func_sig = signature(func)
#     193 # Map *args/**kwargs to the function signature
#
# File c:\Users\black\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1517, in fbeta_score(y_true, y_pred, beta, labels, pos_label, average, sample_weight, zero_division)
#    1336 @validate_params(
#    1337     {
#    1338         "y_true": ["array-like", "sparse matrix"],
#    (...)
#    1365     zero_division="warn",
#    1366 ):
#    1367     """Compute the F-beta score.
#    1368
#    1369     The F-beta score is the weighted harmonic mean of precision and recall,
#    (...)
#    1514     0.12...
#    1515     """
# -> 1517     _, _, f, _ = precision_recall_fscore_support(
#    1518         y_true,
#    1519         y_pred,
#    1520         beta=beta,
#    1521         labels=labels,
#    1522         pos_label=pos_label,
#    1523         average=average,
#    1524         warn_for=("f-score",),
#    1525         sample_weight=sample_weight,
#    1526         zero_division=zero_division,
#    1527     )
#    1528     return f
#
# File c:\Users\black\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py:189, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     187 global_skip_validation = get_config()["skip_parameter_validation"]
#     188 if global_skip_validation:
# --> 189     return func(*args, **kwargs)
#     191 func_sig = signature(func)
#     193 # Map *args/**kwargs to the function signature
#
# File c:\Users\black\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1830, in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1661 """Compute precision, recall, F-measure and support for each class.
#    1662
#    1663 The precision is the ratio ``tp / (tp + fp)`` where ``tp`` is the number of
#    (...)
#    1827  array([2, 2, 2]))
#    1828 """
#    1829 _check_zero_division(zero_division)
# -> 1830 labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1832 # Calculate tp_sum, pred_sum, true_sum ###
#    1833 samplewise = average == "samples"
#
# File c:\Users\black\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1596, in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1593     raise ValueError("average has to be one of " + str(average_options))
#    1595 y_true, y_pred = attach_unique(y_true, y_pred)
# -> 1596 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    1597 # Convert to Python primitive type to avoid NumPy type / Python str
#    1598 # comparison. See https://github.com/numpy/numpy/issues/6784
#    1599 present_labels = _tolist(unique_labels(y_true, y_pred))
#
# File c:\Users\black\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:99, in _check_targets(y_true, y_pred)
#      97 xp, _ = get_namespace(y_true, y_pred)
#      98 check_consistent_length(y_true, y_pred)
# ---> 99 type_true = type_of_target(y_true, input_name="y_true")
#     100 type_pred = type_of_target(y_pred, input_name="y_pred")
#     102 y_type = {type_true, type_pred}
#
# File c:\Users\black\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\multiclass.py:333, in type_of_target(y, input_name, raise_unknown)
#     330 if sparse_pandas:
#     331     raise ValueError("y cannot be class 'SparseSeries' or 'SparseArray'")
# --> 333 if is_multilabel(y):
#     334     return "multilabel-indicator"
#     336 # DeprecationWarning will be replaced by ValueError, see NEP 34
#     337 # https://numpy.org/neps/nep-0034-infer-dtype-is-object.html
#     338 # We therefore catch both deprecation (NumPy < 1.24) warning and
#     339 # value error (NumPy >= 1.24).
#
# File c:\Users\black\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\multiclass.py:172, in is_multilabel(y)
#     170 warnings.simplefilter("error", VisibleDeprecationWarning)
#     171 try:
# --> 172     y = check_array(y, dtype=None, **check_y_kwargs)
#     173 except (VisibleDeprecationWarning, ValueError) as e:
#     174     if str(e).startswith("Complex data not supported"):
#
# File c:\Users\black\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:885, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     882 ensure_all_finite = _deprecate_force_all_finite(force_all_finite, ensure_all_finite)
#     884 if isinstance(array, np.matrix):
# --> 885     raise TypeError(
#     886         "np.matrix is not supported. Please convert to a numpy array with "
#     887         "np.asarray. For more information see: "
#     888         "https://numpy.org/doc/stable/reference/generated/numpy.matrix.html"
#     889     )
#     891 xp, is_array_api_compliant = get_namespace(array)
#     893 # store reference to original array to check if copy is needed when
#     894 # function returns
#
# TypeError: np.matrix is not supported. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html

# %%
model = VGG16()
model.summary()
fit_evaluate(model,Xm_train,ym_train,Xm_test,ym_test,16,30,4)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 4, 4, 512)         14714688
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 8192)              32768
# _________________________________________________________________
# dense_5 (Dense)              (None, 512)               4194816
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 19,114,947
# Trainable params: 4,383,875
# Non-trainable params: 14,731,072
# _________________________________________________________________
# Epoch 1/30
# 38/38 [==============================] - 2s 28ms/step - loss: 2.1444 - acc: 0.4328 - val_loss: 0.5517 - val_acc: 0.7015
# Epoch 2/30
# 38/38 [==============================] - 1s 20ms/step - loss: 1.1508 - acc: 0.7201 - val_loss: 0.3117 - val_acc: 0.9104
# Epoch 3/30
# 38/38 [==============================] - 1s 21ms/step - loss: 0.7586 - acc: 0.8276 - val_loss: 0.3177 - val_acc: 0.9403
# Epoch 4/30
# 38/38 [==============================] - 1s 19ms/step - loss: 0.5068 - acc: 0.8967 - val_loss: 0.2611 - val_acc: 0.9403
# Epoch 5/30
# 38/38 [==============================] - 1s 19ms/step - loss: 0.5145 - acc: 0.8969 - val_loss: 0.2374 - val_acc: 0.9403
# Epoch 6/30
# 38/38 [==============================] - 1s 19ms/step - loss: 0.4768 - acc: 0.9165 - val_loss: 0.2741 - val_acc: 0.9403
# Epoch 7/30
# 38/38 [==============================] - 1s 19ms/step - loss: 0.3733 - acc: 0.9306 - val_loss: 0.1810 - val_acc: 0.9254
# Epoch 8/30
# 38/38 [==============================] - 1s 18ms/step - loss: 0.3014 - acc: 0.9264 - val_loss: 0.2368 - val_acc: 0.8955
# Epoch 9/30
# 38/38 [==============================] - 1s 19ms/step - loss: 0.1876 - acc: 0.9607 - val_loss: 0.2548 - val_acc: 0.9254
# Epoch 10/30
# 38/38 [==============================] - 1s 19ms/step - loss: 0.2898 - acc: 0.9346 - val_loss: 0.1492 - val_acc: 0.9403
# Epoch 11/30
# 38/38 [==============================] - 1s 19ms/step - loss: 0.4316 - acc: 0.9328 - val_loss: 0.2575 - val_acc: 0.9552
# Epoch 12/30
# 38/38 [==============================] - 1s 19ms/step - loss: 0.1133 - acc: 0.9673 - val_loss: 0.3210 - val_acc: 0.9552
# Epoch 13/30
# 38/38 [==============================] - 1s 19ms/step - loss: 0.1906 - acc: 0.9445 - val_loss: 0.2400 - val_acc: 0.9552
# Epoch 14/30
# 38/38 [==============================] - 1s 19ms/step - loss: 0.2173 - acc: 0.9509 - val_loss: 0.2823 - val_acc: 0.9403
# Restoring model weights from the end of the best epoch.
# Epoch 00014: early stopping
# 19/19 [==============================] - 0s 23ms/step - loss: 0.0307 - acc: 0.9899
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1492 - acc: 0.9403
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0739 - acc: 0.9744
# Train accuracy = 0.9899328947067261
# Validation accuracy = 0.9402984976768494
# Test accuracy = 0.9743589758872986
# f1_measure = 0.9742451968508915
# KAPPA = 0.9557767418420058
# roc_area = 0.9988796961569566

# %%
base_model = tf.keras.applications.VGG19(
    include_top=False,
    weights="imagenet",
    input_tensor=None,
    input_shape=img_shape,
    pooling=None
)

for l in base_model.layers:
    l.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 1s 0us/step

# %%
def VGG19():

    model = Sequential()
    model.add(base_model)
    
    model.add(Flatten())
    model.add(BatchNormalization())
    model.add(Dense(128,activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(32,activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(3,activation='softmax'))
    
    model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['acc'])
    
    return model

# %%
model = VGG19()
model.summary()
fit_evaluate(model,X_train,y_train,X_test,y_test,16,30,4)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg19 (Functional)           (None, 4, 4, 512)         20024384
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 8192)              32768
# _________________________________________________________________
# dense_10 (Dense)             (None, 128)               1048704
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 32)                4128
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_12 (Dense)             (None, 3)                 99
# =================================================================
# Total params: 21,110,083
# Trainable params: 1,069,315
# Non-trainable params: 20,040,768
# _________________________________________________________________
# Epoch 1/30
# 38/38 [==============================] - 2s 31ms/step - loss: 1.5118 - acc: 0.4864 - val_loss: 0.9201 - val_acc: 0.5522
# Epoch 2/30
# 38/38 [==============================] - 1s 21ms/step - loss: 1.0672 - acc: 0.6035 - val_loss: 0.8166 - val_acc: 0.6269
# Epoch 3/30
# 38/38 [==============================] - 1s 21ms/step - loss: 0.8322 - acc: 0.6993 - val_loss: 0.7850 - val_acc: 0.7313
# Epoch 4/30
# 38/38 [==============================] - 1s 21ms/step - loss: 0.6895 - acc: 0.7404 - val_loss: 0.7446 - val_acc: 0.7164
# Epoch 5/30
# 38/38 [==============================] - 1s 21ms/step - loss: 0.7428 - acc: 0.7062 - val_loss: 0.6849 - val_acc: 0.7015
# Epoch 6/30
# 38/38 [==============================] - 1s 22ms/step - loss: 0.6674 - acc: 0.7733 - val_loss: 0.6629 - val_acc: 0.7015
# Epoch 7/30
# 38/38 [==============================] - 1s 21ms/step - loss: 0.5728 - acc: 0.7950 - val_loss: 0.6167 - val_acc: 0.7015
# Epoch 8/30
# 38/38 [==============================] - 1s 21ms/step - loss: 0.4706 - acc: 0.8371 - val_loss: 0.6530 - val_acc: 0.7164
# Epoch 9/30
# 38/38 [==============================] - 1s 24ms/step - loss: 0.5434 - acc: 0.7888 - val_loss: 0.6860 - val_acc: 0.7015
# Epoch 10/30
# 38/38 [==============================] - 1s 22ms/step - loss: 0.4030 - acc: 0.8353 - val_loss: 0.6922 - val_acc: 0.7313
# Epoch 11/30
# 38/38 [==============================] - 1s 24ms/step - loss: 0.3486 - acc: 0.8511 - val_loss: 0.6512 - val_acc: 0.7164
# Restoring model weights from the end of the best epoch.
# Epoch 00011: early stopping
# 19/19 [==============================] - 1s 30ms/step - loss: 0.4226 - acc: 0.9094
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6167 - acc: 0.7015
# 4/4 [==============================] - 0s 26ms/step - loss: 0.6396 - acc: 0.7009
# Train accuracy = 0.9093959927558899
# Validation accuracy = 0.7014925479888916
# Test accuracy = 0.7008547186851501
# f1_measure = 0.6978428978428978
# KAPPA = 0.5054347826086957
# roc_area = 0.8805290585566817

# %%
model = VGG19()
model.summary()
fit_evaluate(model,Xm_train,ym_train,Xm_test,ym_test,16,30,4)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg19 (Functional)           (None, 4, 4, 512)         20024384
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 8192)              32768
# _________________________________________________________________
# dense_13 (Dense)             (None, 128)               1048704
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 32)                4128
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_15 (Dense)             (None, 3)                 99
# =================================================================
# Total params: 21,110,083
# Trainable params: 1,069,315
# Non-trainable params: 20,040,768
# _________________________________________________________________
# Epoch 1/30
# 38/38 [==============================] - 2s 31ms/step - loss: 0.9623 - acc: 0.7362 - val_loss: 0.4926 - val_acc: 0.7313
# Epoch 2/30
# 38/38 [==============================] - 1s 21ms/step - loss: 0.6711 - acc: 0.8702 - val_loss: 0.4334 - val_acc: 0.8955
# Epoch 3/30
# 38/38 [==============================] - 1s 21ms/step - loss: 0.4930 - acc: 0.8931 - val_loss: 0.3152 - val_acc: 0.8806
# Epoch 4/30
# 38/38 [==============================] - 1s 22ms/step - loss: 0.2359 - acc: 0.9235 - val_loss: 0.3107 - val_acc: 0.9104
# Epoch 5/30
# 38/38 [==============================] - 1s 22ms/step - loss: 0.4875 - acc: 0.9331 - val_loss: 0.2475 - val_acc: 0.9104
# Epoch 6/30
# 38/38 [==============================] - 1s 22ms/step - loss: 0.4391 - acc: 0.9067 - val_loss: 0.2951 - val_acc: 0.9254
# Epoch 7/30
# 38/38 [==============================] - 1s 21ms/step - loss: 0.2550 - acc: 0.9418 - val_loss: 0.2660 - val_acc: 0.9254
# Epoch 8/30
# 38/38 [==============================] - 1s 21ms/step - loss: 0.3150 - acc: 0.9417 - val_loss: 0.2826 - val_acc: 0.9104
# Epoch 9/30
# 38/38 [==============================] - 1s 21ms/step - loss: 0.2129 - acc: 0.9599 - val_loss: 0.3428 - val_acc: 0.9104
# Restoring model weights from the end of the best epoch.
# Epoch 00009: early stopping
# 19/19 [==============================] - 1s 28ms/step - loss: 0.0555 - acc: 0.9883
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2475 - acc: 0.9104
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0600 - acc: 0.9829
# Train accuracy = 0.9882550239562988
# Validation accuracy = 0.9104477763175964
# Test accuracy = 0.9829059839248657
# f1_measure = 0.9827486499128291
# KAPPA = 0.9703872437357631
# roc_area = 0.9996769097205971
